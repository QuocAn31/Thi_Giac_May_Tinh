# %%
from imgtools import *

# %%
dir = 'C:/Picture'

# %%
imgs = get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (1000, 758)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x758>
# (1000, 758)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x758>
# (201, 250)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=201x250>
# (168, 300)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x300>
# (259, 194)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>
# (266, 190)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=266x190>
