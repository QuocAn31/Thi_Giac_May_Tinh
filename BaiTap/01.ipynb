# %%
from PIL import Image

# %%
dir = r'C:\Picture/1.JPG'

# %%
print(dir)

# %%
img01 = Image.open(dir)

# %%
img01 = Image.open(dir)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x758>

# %%
print("Định dạng ảnh: ", img01.format)
# Out:
# Định dạng ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (1000, 758)

# %%
new_img_01_path_jpg = r'C:\Picture\1.JPG'
new_img_png_01_path = r'C:\Picture\1.PNG'

img01.save(new_img_01_path_jpg)
img01.save(new_img_png_01_path)

# %%
img01.close()
